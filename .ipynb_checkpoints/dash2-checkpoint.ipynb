# %% [markdown]
# ### NYC Inmates

# %% [markdown]
# ###### This notebook aims to analyse and visualise inmate data collected by New York City prisons in order to answer questions  such as the possibility of a relationship between the mental health of an inmate and violence and whether or not prisons need to improve mental health facilities.

# %% [markdown]
# ###### 1. Data Cleaning
# ###### 2. Exploratory Data Analysis
# ###### 3. Data Visualisation

# %%
#reading in the data
import pandas as pd
from scipy import stats
import plotly as go
df = pd.read_csv('daily-inmates-in-custody.csv')

# %%
# checking missing values
df.isnull().sum()
# Out:
# INMATEID                 0
# ADMITTED_DT              0
# DISCHARGED_DT         7151
# CUSTODY_LEVEL          156
# BRADH                    0
# RACE                    24
# GENDER                  24
# AGE                     13
# INMATE_STATUS_CODE       0
# SEALED                   0
# SRG_FLG                  0
# TOP_CHARGE             872
# INFRACTION               0
# dtype: int64

# %%
df = df.replace(to_replace='W',value='White')
df = df.replace(to_replace='B',value='Black')
df = df.replace(to_replace='O',value='Other Pacific Islander')
df = df.replace(to_replace='A',value='Asian')
df = df.replace(to_replace='I',value='Indian')

# %%
race = df['RACE'].value_counts(normalize=False).to_frame()
rlabels = race.index.tolist()
rvalues = race['RACE'].tolist()
race_age = df[(df['SRG_FLG']=='Y') & (df['RACE'])]
race = race_age['RACE'].value_counts(normalize=False).to_frame()
ralabels = race.index.tolist()
ravalues = race['RACE'].tolist()

# %% [markdown]
# ###### All the values in the DISCHARGED_DT column are missing so I am dropping the column.

# %%
df.dropna(axis=1,how='all')
# Out:
#       INMATEID              ADMITTED_DT CUSTODY_LEVEL BRADH  \
# 0       152258  2018-08-24T01:46:33.000           MIN     Y
# 1     20124341  2018-06-13T00:59:55.000           MAX     Y
# 2       155323  2019-02-05T12:04:19.000           MAX     N
# 3       118754  2019-02-24T18:22:23.000           MAX     N
# 4     20203998  2019-05-02T01:35:22.000           MAX     Y
# 5     20200982  2019-08-09T18:03:42.000           MIN     N
# 6     20100177  2019-06-29T12:49:17.000           MIN     N
# 7     20006004  2019-05-23T13:19:00.000           MED     N
# 8     20173572  2019-08-13T11:19:00.000           MED     N
# 9        49115  2019-02-12T20:02:00.000           MIN     N
# 10       52407  2019-08-15T16:47:00.000           MED     Y
# 11       20274  2019-08-18T11:25:34.000           MIN     N
# 12    10008398  2019-04-09T17:11:00.000           MAX     N
# 13    20202447  2019-02-26T16:25:00.000           MIN     N
# 14    20201656  2019-08-04T00:56:00.000           MED     N
# 15    20206560  2019-08-23T11:50:01.000           NaN     N
# 16       86172  2018-09-07T14:14:05.000           MED     Y
# 17    20141900  2019-08-19T14:34:18.000           MED     Y
# 18    20098825  2019-08-10T20:04:23.000           MIN     Y
# 19       62293  2019-03-07T16:12:01.000           MIN     Y
# 20    20202688  2019-03-08T13:13:10.000           MAX     N
# 21    20206522  2019-08-21T17:24:56.000           MED     N
# 22    20205165  2019-06-20T19:16:38.000           MED     N
# 23    20028515  2019-07-18T13:23:05.000           MIN     N
# 24      150713  2019-02-15T16:51:05.000           MIN     Y
# 25    20093288  2019-08-13T12:05:31.000           MIN     N
# 26    20124830  2019-07-29T14:50:19.000           MED     Y
# 22    Other Pacific Islander      M  60.0                 DE      N       N
# 23                     Black      M  42.0                 DE      N       N
# 24    Other Pacific Islander      M  36.0                 CS      N       N
# 25                     Black      M  58.0                 DE      N       N
# 26                     Black      M  54.0                DPV      N       N
# 27                     Black      M  52.0                 DE      N       N
# 28    Other Pacific Islander      M  52.0                 DE      N       N
# 29    Other Pacific Islander      M  22.0                DPV      N       Y
# ...                      ...    ...   ...                ...    ...     ...
# 7121                   Black      M  42.0                 DE      N       N
# 7122  Other Pacific Islander      M  47.0                 DE      N       N
# 7123  Other Pacific Islander      M  62.0                 DE      N       N
# 7124                   Black      M  23.0                 DE      N       Y
# 7125                   Black      M  38.0                 DE      N       N
# 7126                   Black      M  43.0                 DE      N       N
# 7127  Other Pacific Islander      M  22.0                 DE      N       Y
# 7128                   Black      M  46.0                 DE      N       N
# 7129  Other Pacific Islander      M  22.0                 DE      N       Y
# 7130                   Black      M  25.0                 DE      N       Y
# 7131  Other Pacific Islander      M  25.0                 DE      N       Y
# 7132  Other Pacific Islander      M  37.0                 DE      N       N
# 7133                   Black      M  54.0                 DE      N       N
# 7134                   Black      M  38.0                 DE      N       N
# 7135                   Black      M  35.0                 DE      N       Y
# 7136  Other Pacific Islander      M  45.0                 DE      N       N
# 7137                   White      M  40.0                 DE      N       N
# 7138                   White      M  48.0                 DE      N       N
# 7139  Other Pacific Islander      M  46.0                DEP      N       N
# 7140                   White      M  40.0                 DE      N       N
# 7141                   Black      M  22.0                 DE      N       N
# 7142                   Black      M  37.0                 DE      N       N
# 7143                   Black      M  48.0                 DE      N       N
# 7144                   Black      M  40.0                 DE      N       Y
# 7145                   Black      M  27.0                DEP      N       Y
# 7146                   Black      M  22.0                 DE      N       N
# 7147                   Black      M  43.0                 DE      N       N
# 7148  Other Pacific Islander      M  52.0                 DE      N       N
# 7149                   Black      M  25.0                 DE      N       N
# 7150                   Black      M  32.0                 DE      N       Y
#
#       TOP_CHARGE INFRACTION
# 0         140.25          N
# 1         125.25          Y
# 2         105.05          Y
# 3            NaN          Y
# 4         125.25          Y
# 5         160.05          N
# 6         155.25          N
# 7         155.30          N
# 8         160.15          N
# 9     110-140.20          N
# 10        125.25          N
# 11        130.52          N
# 12    FOA 900.00          Y
# 13        155.40          N
# 14        140.25          N
# 15        240.50          N
# 16        160.15          N
# 17        155.25          N
# 18     AC 000.00          N
# 19        140.25          N
# 20        125.25          Y
# 21    110-125.25          N
# 22        125.25          N
# 23        265.02          N
# 24        140.20          N
# 25           VOP          N
# 26           NaN          N
# 27        220.03          N
# 28           NaN          N
# 29           NaN          N
# ...          ...        ...
# 7121      125.25          N
# 7122      125.25          N
# 7123      220.43          N
# 7124      220.16          Y
# 7125      125.27          N
# 7126      125.25          N
# 7127      120.05          N
# 7128  110-125.25          N
# 7129      160.15          Y
# 7130      125.27          Y
# 7131      265.03          N
# 7132      130.75          Y
# 7133      121.12          N
# 7134      265.03          N
# 7135  110-125.25          Y
# 7136      105.10          Y
# 7137      265.03          Y
# 7138      140.25          Y
# 7139      140.25          N
# 7140      130.96          N
# 7141      230.34          Y
# 7142      130.65          N
# 7143      140.25          N
# 7144      125.25          Y
# 7145      120.10          Y
# 7146      160.15          Y
# 7147      220.41          N
# 7148      130.65          N
# 7149     VTL 511          N
# 7150      125.25          Y
#
# [7151 rows x 12 columns]

# %% [markdown]
# ###### The null hypothesis states that there is no relationship between mental health and being potentially violent.
# ###### The alternative hypothesis states that there is a strong relationship between inmates under mental observation and being potentially violent.

# %% [markdown]
# ### Significance Test

# %%
from scipy import stats

r = stats.pearsonr((df['BRADH'] == 'Y'),(df['INFRACTION'] == 'Y'))
r
# Out:
# (0.17296678612605065, 3.823568226592532e-49)

# %% [markdown]
# ###### A p value of 3.8e-49 disproves the null hypothesis and leads me to accepting the alternative hypothesis which states that inmates under mental observation are in fact potentially violent. This shows that there is statistical significance between the two variables.

# %% [markdown]
# ##### A count of inmates who are under mental observation and have an infraction

# %%
mental_obs_custody = df[(df.BRADH == 'Y') & (df.INFRACTION == 'Y')]
mental_obs_custody.count()
# Out:
# INMATEID              1313
# ADMITTED_DT           1313
# DISCHARGED_DT            0
# CUSTODY_LEVEL         1313
# BRADH                 1313
# RACE                  1312
# GENDER                1312
# AGE                   1313
# INMATE_STATUS_CODE    1313
# SEALED                1313
# SRG_FLG               1313
# TOP_CHARGE            1219
# INFRACTION            1313
# dtype: int64

# %% [markdown]
#  ###### This is a count of all inmates who are under mental observation and are potentially harmful.

# %%
mental_custody = mental_obs_custody['CUSTODY_LEVEL'].value_counts(normalize=False).to_frame()
label = mental_custody.index.tolist()
value = mental_custody['CUSTODY_LEVEL'].tolist()

# %% [markdown]
# ##### Distributions of custody levels of inmates under metal observation

# %%
mental = df[(df['BRADH'] == 'Y') & (df['CUSTODY_LEVEL'])]
mental_custody_level = mental['CUSTODY_LEVEL'].value_counts(normalize=False).to_frame()
label = mental_custody_level.index.tolist()
value = mental_custody_level['CUSTODY_LEVEL'].tolist()

# %% [markdown]
# ##### A count of inmates under mental observation

# %%
date = df['BRADH'].value_counts(normalize=False).to_frame()
labels = date.index.tolist()

values = date['BRADH'].tolist()

# %% [markdown]
# ##### Distribution of inmates across all custody levels

# %%
custodyl = df['CUSTODY_LEVEL'].value_counts(normalize=False).to_frame()
labels = custodyl.index.tolist()
values = custodyl['CUSTODY_LEVEL'].tolist()

# %% [markdown]
# ##### Distribution of races

# %%
race = df['RACE'].value_counts(normalize=False).to_frame()
labels = race.index.tolist()
values = race['RACE'].tolist()

# %% [markdown]
# #### Inmates who are affiliated with a gang

# %%
date = df['SRG_FLG'].value_counts(normalize=False).to_frame()
labels = date.index.tolist()

values = date['SRG_FLG'].tolist()

# %% [markdown]
# #### Distribution of inmates' ages

# %%
age = df['AGE'].value_counts(normalize=False).to_frame()
labels = age.index.tolist()
values = age['AGE'].tolist()

# %% [markdown]
# #### Inmates with infractions

# %%
infract = df['INFRACTION'].value_counts(normalize=False).to_frame()
labels = infract.index.tolist()
values = infract['INFRACTION'].tolist()

# %% [markdown]
# #### Gender

# %%
gender = df['GENDER'].value_counts(normalize=False).to_frame()
label = gender.index.tolist()
value = gender['GENDER'].tolist()
